# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### TIME TAKEN TO CONVERT 30,000 IMAGES TO GREYSCALE IN PYTHON ####

# %%
df = pd.read_csv('./PYTHON/grey_scale_images.csv')
df
# Out:
#     Threads     Python
# 0         1  2571.6565
# 1         2   971.4161
# 2         3   567.8947
# 3         4   393.2980
# 4         5   270.6599
# 5         6   256.3903
# 6         7   196.6580
# 7         8   195.3257
# 8         9   217.2191
# 9        10   223.5680
# 10       11   210.2702

# %%
plt.rcParams["figure.figsize"] = [25, 15]
plt.rcParams.update({'font.size': 22})

x = df['Threads']
y = df['Python']

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (sec)', fontsize=25)

for i, j in zip(x, y):
    plt.annotate(str(j), xy=(i, j))

plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(y)+200, 200))
plt.plot(x, y, linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

plt.ylim([0, max(y)+200])

plt.show()

# %% [markdown]
# ### RESULT  ###
#
# #### 8 THREADS TAKE THE MINIMUM TIME ####

# %% [markdown]
# #### TIME TAKEN TO CONVERT 30,000 IMAGES TO GREYSCALE IN C++ ####

# %%
df_grayscale_cpp = pd.read_csv('./C++/grayscale_images_C++.csv')
df_grayscale_cpp
# Out:
#     Threads      Time
# 0         1  1125.220
# 1         2   679.595
# 2         3   595.815
# 3         4   572.605
# 4         5   557.831
# 5         6   543.472
# 6         7   539.087
# 7         8   543.340
# 8         9   529.463
# 9        10   552.532
# 10       11   573.544

# %%
plt.rcParams["figure.figsize"] = [25, 15]
plt.rcParams.update({'font.size': 22})

x = df_grayscale_cpp['Threads']
y = df_grayscale_cpp['Time']

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (sec)', fontsize=25)

for i, j in zip(x, y):
    plt.annotate(str(j), xy=(i, j))

plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(y)+200, 200))
plt.plot(x, y, linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

plt.ylim([0, max(y)+200])

plt.show()

# %% [markdown]
# ### RESULT  ###
#
# #### 9 THREADS TAKE THE MINIMUM TIME ####

# %% [markdown]
# #### COMPARISION OF TIME TAKEN BY C++ AND PYTHON TO CONVERT 30,000 IMAGES TO GRAYSCALE ####

# %%
plt.rcParams["figure.figsize"] = [20, 20]
plt.rcParams.update({'font.size': 22})


x = df_grayscale_cpp['Threads']
y1 = df_grayscale_cpp['Time']/60
y2 = df['Python']/60

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (min)', fontsize=25)

for i, j in zip(x, y1):
    plt.annotate(str('%.2f' % j), xy=(i, j))

for i, j in zip(x, y2):
    plt.annotate(str('%.2f' % j), xy=(i, j))


plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(max(y1), max(y2))+2, 2))
plt.plot(x, y1, linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10, color='blue', label="C++")
plt.plot(x, y2, marker='o', color='green', linestyle='dashed',
         markerfacecolor='green', markersize=10, label="Python")

plt.legend(loc="upper right")
plt.ylim([0, max(max(y1), max(y2))+2])
plt.show()

# %% [markdown]
# #### TIME TAKEN TO COPY 10,000 IMAGES FROM ONE FOLDER TO ANOTHER IN PYTHON ####

# %%
df_copy_images_py = pd.read_csv('./PYTHON/copy_images_python.csv')
df_copy_images_py
# Out:
#     Threads       Time
# 0         1  1944.7918
# 1         2  1002.5599
# 2         3   521.8971
# 3         4   281.8760
# 4         5   128.3275
# 5         6    33.3678
# 6         7    25.3731
# 7         8    23.5140
# 8         9    24.4659
# 9        10    29.7853
# 10       11    40.4354

# %%
plt.rcParams["figure.figsize"] = [25, 15]
plt.rcParams.update({'font.size': 22})

x = df_copy_images_py['Threads']
y = df_copy_images_py['Time']

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (sec)', fontsize=25)

for i, j in zip(x, y):
    plt.annotate(str(j), xy=(i, j))

plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(y)+200, 200))
plt.plot(x, y, linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

plt.ylim([0, max(y)+200])

plt.show()

# %% [markdown]
# #### TIME TAKEN TO COPY 10,000 IMAGES FROM ONE FOLDER TO ANOTHER IN C++ ####

# %%
df_copy_images_cpp = pd.read_csv('./C++/copy_images_cpp.csv')
df_copy_images_cpp
# Out:
#     Threads      Time
# 0         1  10.58510
# 1         2   7.47719
# 2         3   5.51071
# 3         4   4.70511
# 4         5   4.28205
# 5         6   4.60954
# 6         7   5.51910
# 7         8   7.13521
# 8         9   8.88715
# 9        10   6.55615
# 10       11   8.65341

# %%
plt.rcParams["figure.figsize"] = [25, 15]
plt.rcParams.update({'font.size': 22})

x = df_copy_images_cpp['Threads']
y = df_copy_images_cpp['Time']

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (sec)', fontsize=25)

for i, j in zip(x, y):
    plt.annotate(str(j), xy=(i, j))

plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(y)+2, 1))
plt.plot(x, y, linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)

plt.ylim([0, max(y)+2])
plt.show()

# %% [markdown]
# #### RESULT ####
#
# #### 5 THREADS TAKE THE MINIMUM TIME ####

# %% [markdown]
# #### COMPARISION OF TIME TAKEN BY C++ AND PYTHON TO COPY 10,000 IMAGES FROM ONE FOLDER TO ANOTHER ####

# %%
plt.rcParams["figure.figsize"] = [30, 30]
plt.rcParams.update({'font.size': 16})


x = df_copy_images_cpp['Threads']
y1 = df_copy_images_cpp['Time']/60
y2 = df_copy_images_py['Time']/60

plt.xlabel('No.  of  Threads', fontsize=25)
plt.ylabel('Time taken (min)', fontsize=25)

for i, j in zip(x, y1):
    plt.annotate(str('%.2f' % j), xy=(i, j))

for i, j in zip(x, y2):
    plt.annotate(str('%.2f' % j), xy=(i, j))


plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.yticks(np.arange(0, max(max(y1), max(y2))+2, 1))
plt.plot(x, y1, linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10, color='blue', label="C++")
plt.plot(x, y2, marker='o', color='green', linestyle='dashed',
         markerfacecolor='green', markersize=10, label="Python")

plt.legend(loc="upper right")
plt.ylim([0, max(max(y1), max(y2))+0.5])
plt.show()
